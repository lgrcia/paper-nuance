# %%
import pandas as pd

targets = pd.read_csv("../data/tess-ultra-fast-rotators-brighter-mag14.csv").Name.values

# %%
targets
# Out:
# array([ 70775324,  70788006,  70788050, 155896947, 469939293, 425937008,
#         40047077, 246855533, 246891813, 251879914,  63907355, 234523931,
#        268717977, 248945338, 183641863,  41862291, 344225524, 257397333,
#        248986951, 206617113, 164695231,  29923559,  10863087, 229142295,
#         33525679, 423389014, 250363198, 231057252, 268765554,  72667734,
#         72706694, 146245416, 420031513,  63958788, 122504261, 318839580,
#         35857994, 220522527, 368644381,  23126920, 439913926, 207171025,
#        301020663, 137861381, 370138553, 207211020, 176852837, 207238086,
#        160008311, 142884342, 314825931, 257567390, 142960339, 301463279,
#        416740234, 262924431, 197847859, 237918270, 121091696, 401945770,
#         32068898, 388977683,  89205615, 178241984, 457191730,  44646061,
#        242985065, 237940278, 198034151,  44795539, 152475404, 168750720,
#        250131154,  25153167, 139547745,  70991709,  33866201, 435939517,
# ...
