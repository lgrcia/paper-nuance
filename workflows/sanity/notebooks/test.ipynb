# %%
import numpy as np
import matplotlib.pyplot as plt
from nuance.utils import phase

time, flux, error = np.load("../data/lightcurve.npy")
params = np.load("../data/params.npy")
filename = "../data/injected/100.npy"
i = int(filename.split("/")[-1].split(".")[0])
flux = np.load(filename)
period, _ = params[i]
plt.plot(phase(time, 0, period), flux, ".", c="0.8")

# %%
import numpy as np
import astropy.units as u
from astropy.timeseries import BoxLeastSquares


periods = np.linspace(0.5, 6, 3000)
model = BoxLeastSquares(time, flux, dy=error)
periodogram = model.power(periods, 0.03)
results.period[np.argmax(results.power)]

# %%
import matplotlib.pyplot as plt

plt.plot(periodogram.period, periodogram.power)

# %%
# add blanck and white rectangle in plot legend
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3], label="test")
ax.legend()
ax.legend(
    handles=[
        plt.Patch(facecolor="w", edgecolor="k"),
        plt.Patch(facecolor="k", edgecolor="k"),
    ],
    labels=["detected", "not detected"],
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 10
#       6 ax.plot([1, 2, 3], label="test")
#       7 ax.legend()
#       8 ax.legend(
#       9     handles=[
# ---> 10         plt.Patch(facecolor="w", edgecolor="k"),
#      11         plt.Patch(facecolor="k", edgecolor="k")
#      12     ], labels=["detected", "not detected"])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Patch'

# %%
n = np.arange(20)
x, y = np.meshgrid(n, n)

# %%
period.min(), period.max()
depth.min(), depth.max()
# Out:
# (0.0002609267879521456, 0.0006779076806833005)

# %%
np.unique(period)
# Out:
# array([0.3       , 0.41578947, 0.53157895, 0.64736842, 0.76315789,
#        0.87894737, 0.99473684, 1.11052632, 1.22631579, 1.34210526,
#        1.45789474, 1.57368421, 1.68947368, 1.80526316, 1.92105263,
#        2.03684211, 2.15263158, 2.26842105, 2.38421053, 2.5       ])

# %%
files
# Out:
# ['../data/results/nuance/118.yaml',
#  '../data/results/nuance/40.yaml',
#  '../data/results/nuance/231.yaml',
#  '../data/results/nuance/374.yaml',
#  '../data/results/nuance/17.yaml',
#  '../data/results/nuance/266.yaml',
#  '../data/results/nuance/289.yaml',
#  '../data/results/nuance/323.yaml',
#  '../data/results/nuance/159.yaml',
#  '../data/results/nuance/270.yaml',
#  '../data/results/nuance/335.yaml',
#  '../data/results/nuance/56.yaml',
#  '../data/results/nuance/227.yaml',
#  '../data/results/nuance/362.yaml',
#  '../data/results/nuance/175.yaml',
#  '../data/results/nuance/319.yaml',
#  '../data/results/nuance/122.yaml',
#  '../data/results/nuance/95.yaml',
#  '../data/results/nuance/134.yaml',
#  '../data/results/nuance/7.yaml',
#  '../data/results/nuance/83.yaml',
#  '../data/results/nuance/358.yaml',
#  '../data/results/nuance/163.yaml',
#  '../data/results/nuance/397.yaml',
#  '../data/results/nuance/378.yaml',
#  '../data/results/nuance/114.yaml',
# ...

# %%
files
# Out:
# ['../data/results/nuance/0.yaml',
#  '../data/results/nuance/1.yaml',
#  '../data/results/nuance/2.yaml',
#  '../data/results/nuance/3.yaml',
#  '../data/results/nuance/4.yaml',
#  '../data/results/nuance/5.yaml',
#  '../data/results/nuance/6.yaml',
#  '../data/results/nuance/7.yaml',
#  '../data/results/nuance/8.yaml',
#  '../data/results/nuance/9.yaml',
#  '../data/results/nuance/10.yaml',
#  '../data/results/nuance/11.yaml',
#  '../data/results/nuance/12.yaml',
#  '../data/results/nuance/13.yaml',
#  '../data/results/nuance/14.yaml',
#  '../data/results/nuance/15.yaml',
#  '../data/results/nuance/16.yaml',
#  '../data/results/nuance/17.yaml',
#  '../data/results/nuance/18.yaml',
#  '../data/results/nuance/19.yaml',
#  '../data/results/nuance/20.yaml',
#  '../data/results/nuance/21.yaml',
#  '../data/results/nuance/22.yaml',
#  '../data/results/nuance/23.yaml',
#  '../data/results/nuance/24.yaml',
#  '../data/results/nuance/25.yaml',
#  '../data/results/nuance/26.yaml',
# ...

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.title(r"{\ttfamily My Title}")
plt.show()

# %%
import matplotlib.pyplot as plt

# Change the backend to pgf
plt.switch_backend("pgf")

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.title(r"\texttt{My Title}")
plt.show()
plt.savefig("test.pdf")
# Out:
# /var/folders/7v/d8bs1hz144s2ypqglv245hp40000gn/T/ipykernel_74699/3915892455.py:11: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
