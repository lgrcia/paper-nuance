# %%
import subprocess

print(subprocess.check_output(["git", "-C", "/Users/lgrcia/code/nuance", "rev-parse", "HEAD"]))
# Out:
# b'8e40d99f63194f1d2a8c5779d3ae4c42dbc8cbca\n'

# %%
import numpy as np

a = np.load("0de4933_snr.npy")
b = np.load("8e40d99_snr.npy")
c = np.load("8e40d99_modified_snr.npy")

# %%
np.allclose(a, c)
# Out:
# False

# %%
import matplotlib.pyplot as plt

plt.plot(a)
#plt.plot(b)
plt.plot(c)

# %%
np.allclose(b, c)
# Out:
# True
